# %% [markdown]
# # Getting started

# %%
1+1
# Out:
# 2

# %%
from arcgis import *
from IPython.display import display

# %%
gis = GIS('https://citygov.maps.arcgis.com','phammons_citygov')
# Out:
# Enter password: ········

# %%
items = gis.content.search('*', max_items=999999999)

# %%
for item in items:
    display(item)
# Out:
# <Item title:"City Parks Today and tomorrow" type:Web Mapping Application owner:tamm5602@esri.com_citygov>
# <Item title:"nri_download_m" type:Document Link owner:phammons_citygov>
# <Item title:"Incidents" type:Feature Layer Collection owner:abrown_citygov>
# <Item title:"Sanitary_Sewer_Lines" type:Feature Layer Collection owner:alex8694@esri.com_citygov>
# <Item title:"Parks_Northampton" type:Feature Layer Collection owner:abrown_citygov>
# <Item title:"Allegheny Field Operations Demo" type:Operation View owner:alex8694@esri.com_citygov>
# <Item title:"Locate Treatment Centers Light" type:Web Map owner:phammons_citygov>
# <Item title:"Parcels_H150_MinLot_Other" type:Service Definition owner:patr4089@esri.com_citygov>
# <Item title:"Cases from Pegasys" type:GeoJson owner:phammons_citygov>
# <Item title:"NYCHA_Buildings" type:Feature Layer Collection owner:piya8833@esri.com_citygov>
# <Item title:"GSI_SMP_TYPES" type:Service Definition owner:abrown_citygov>
# ...

# %%
philly = gis.map('Philadelphia')
philly

# %%
philly.add_layer(items[8])
